# %%
from safetensors.torch import load_file
# Out:
# /Users/plat/Documents/Rust/safemetadata/.venv/lib/python3.11/site-packages/torch/_subclasses/functional_tensor.py:258: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
state_dict = load_file("../cleaned.safetensors")
state_dict
# Out:
# {'lora_unet_double_blocks_0_img_attn_proj.alpha': tensor(32., dtype=torch.bfloat16),
#  'lora_unet_double_blocks_0_img_attn_proj.lora_down.weight': tensor([[-0.0055,  0.0120, -0.0085,  ...,  0.0061, -0.0135, -0.0003],
#          [-0.0070,  0.0153, -0.0140,  ..., -0.0173, -0.0168, -0.0137],
#          [-0.0157,  0.0075,  0.0065,  ..., -0.0137, -0.0175, -0.0041],
#          ...,
#          [-0.0092,  0.0150, -0.0039,  ..., -0.0019, -0.0040,  0.0145],
#          [-0.0070, -0.0104,  0.0058,  ..., -0.0132,  0.0064, -0.0023],
#          [-0.0170, -0.0153, -0.0143,  ...,  0.0067, -0.0103, -0.0164]],
#         dtype=torch.bfloat16),
#  'lora_unet_double_blocks_0_img_attn_proj.lora_up.weight': tensor([[-6.1989e-05,  3.1090e-04,  2.3460e-04,  ..., -2.5630e-05,
#            3.5477e-04, -2.7847e-04],
#          [ 2.4796e-04,  7.3242e-04, -8.3447e-05,  ..., -4.0436e-04,
#            1.4603e-05, -1.9264e-04],
#          [-2.2411e-04, -1.6212e-04, -1.4305e-04,  ...,  3.0696e-06,
# ...
