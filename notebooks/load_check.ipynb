# %%
from safetensors.torch import load_file

# %%
state_dict = load_file("../cleaned.safetensors")
state_dict
# Out:
# {'lora_unet_double_blocks_0_img_attn_proj.alpha': tensor(32., dtype=torch.bfloat16),
#  'lora_unet_double_blocks_0_img_attn_proj.lora_down.weight': tensor([[-0.0226, -0.0162,  0.0364,  ...,  0.0034, -0.0153, -0.0330],
#          [ 0.0120,  0.0444, -0.0356,  ..., -0.0205,  0.0654,  0.0601],
#          [ 0.0171, -0.0005, -0.0040,  ...,  0.0153, -0.0250, -0.0083],
#          ...,
#          [-0.0195, -0.0349,  0.0562,  ...,  0.0359, -0.0703, -0.0544],
#          [ 0.0283, -0.0371,  0.0283,  ...,  0.0330, -0.0669, -0.0825],
#          [ 0.0125, -0.0371,  0.0239,  ...,  0.0294, -0.0981, -0.0620]],
#         dtype=torch.bfloat16),
#  'lora_unet_double_blocks_0_img_attn_proj.lora_up.weight': tensor([[-0.0417,  0.0130,  0.0089,  ...,  0.0085,  0.0132,  0.0020],
#          [-0.0127,  0.0049, -0.0164,  ..., -0.0074, -0.0259, -0.0259],
#          [ 0.0659, -0.0537, -0.0635,  ...,  0.0378, -0.0439, -0.0369],
#          ...,
# ...
